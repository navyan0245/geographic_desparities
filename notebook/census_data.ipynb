# %%
import pandas as pd

# %%
census_2021=pd.read_csv('../data/2021_census.csv')

# %%
census_2021.head(7)
# Out:
#    Year                      County Total population   White  \
# 0  2021  Anderson County, Tennessee              NaN     NaN
# 1  2021                      Number              NaN     NaN
# 2  2021                    Estimate           76,683  68,348
# 3  2021        Percent Distribution              NaN     NaN
# 4  2021                    Estimate           76,683  89.10%
# 5  2021       Mean income (dollars)              NaN     NaN
# 6  2021                    Estimate           30,544  31,380
#
#   Black or African American American Indian and Alaska Native   Asian  \
# 0                       NaN                               NaN     NaN
# 1                       NaN                               NaN     NaN
# 2                     2,395                               270   1,069
# 3                       NaN                               NaN     NaN
# 4                     3.10%                             0.40%   1.40%
# ...
